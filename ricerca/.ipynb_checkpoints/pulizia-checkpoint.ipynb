# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
STEROIDS_PATH = '../datasets/anabolic_steroids.csv'
POWERLIFTING_PATH = '../datasets/openpowerlifting-2026-06-20/openpowerlifting-2026-06-20-a9718576.csv'

steroids = pd.read_csv(STEROIDS_PATH)
powerlifting = pd.read_csv(POWERLIFTING_PATH, low_memory=False)

# %%
powerlifting
# Out:
#                       Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0           E.S. Denisenko   F     B       Raw  28.5    24-34          24-39
# 1          I.S. Lebetskaya   F     B       Raw  43.5    40-44          40-49
# 2            K. Yakimovich   F     B       Raw  26.5    24-34          24-39
# 3             A.G. Golneva   F     B       Raw  19.5    20-23          19-23
# 4        E.V. Marunevskaya   F     B       Raw  19.5    20-23          19-23
# ...                    ...  ..   ...       ...   ...      ...            ...
# 3954725   Ibrahim Sandogji   M   SBD       Raw  17.0    16-17          14-18
# 3954726    Feras Alwahhabi   M   SBD       Raw  17.0    16-17          14-18
# 3954727       Musab Alessa   M   SBD       Raw  17.0    16-17          14-18
# 3954728        Ali Alholan   M   SBD       Raw  18.0    18-19          14-18
# 3954729     Alfarooq Eissa   M   SBD       Raw  18.0    18-19          14-18
#
# ...

# %%
powerlifting.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks', 'Glossbrenner',
#        'Goodlift', 'Tested', 'Country', 'State', 'Federation',
#        'ParentFederation', 'Date', 'MeetCountry', 'MeetState', 'MeetTown',
#        'MeetName', 'Sanctioned'],
#       dtype='str')

# %%
# il dataset è enorme, rimuovo le colonne che non mi serviranno

clean_powerlifting = powerlifting[[
    'Sex', 'Age', 'BodyweightKg', 
    'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg',
    'TotalKg', 'Place', 'Dots', 'Wilks', 'Tested', 'Federation', 'Date'
]].copy()

clean_powerlifting
# Out:
#         Sex   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  \
# 0         F  28.5          67.3           NaN           NaN              NaN
# 1         F  43.5          73.2           NaN          90.0              NaN
# 2         F  26.5          60.6           NaN          45.0              NaN
# 3         F  19.5          50.3           NaN          35.0              NaN
# 4         F  19.5          63.7           NaN          42.5              NaN
# ...      ..   ...           ...           ...           ...              ...
# 3954725   M  17.0          64.4         177.5         120.0            215.0
# 3954726   M  17.0          82.9         212.5         112.5            230.0
# 3954727   M  17.0          91.3         242.5         130.0            257.5
# 3954728   M  18.0         103.6         215.0         120.0            255.0
# 3954729   M  18.0         157.3         240.0         130.0            240.0
#
# ...

# %% [markdown]
# ## Place: DD significa Doping Disqualified
# Quindi ci possono essere atleti che usano steroidi anche nei natural

# %% [markdown]
# ## Isolo solo gli anni, senza il resto della data

# %%
clean_powerlifting['Year'] = clean_powerlifting['Date'].str[0:4].astype(int)
clean_powerlifting
# Out:
#         Sex   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  \
# 0         F  28.5          67.3           NaN           NaN              NaN
# 1         F  43.5          73.2           NaN          90.0              NaN
# 2         F  26.5          60.6           NaN          45.0              NaN
# 3         F  19.5          50.3           NaN          35.0              NaN
# 4         F  19.5          63.7           NaN          42.5              NaN
# ...      ..   ...           ...           ...           ...              ...
# 3954725   M  17.0          64.4         177.5         120.0            215.0
# 3954726   M  17.0          82.9         212.5         112.5            230.0
# 3954727   M  17.0          91.3         242.5         130.0            257.5
# 3954728   M  18.0         103.6         215.0         120.0            255.0
# 3954729   M  18.0         157.3         240.0         130.0            240.0
#
# ...

# %%
clean_powerlifting = clean_powerlifting.drop('Date', axis='columns')

# %%
clean_powerlifting = clean_powerlifting.dropna(subset=['Dots', 'Year', 'TotalKg'])
clean_powerlifting
# Out:
#         Sex   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  \
# 1         F  43.5          73.2           NaN          90.0              NaN
# 2         F  26.5          60.6           NaN          45.0              NaN
# 3         F  19.5          50.3           NaN          35.0              NaN
# 4         F  19.5          63.7           NaN          42.5              NaN
# 5         M  30.5          82.0           NaN         132.5              NaN
# ...      ..   ...           ...           ...           ...              ...
# 3954725   M  17.0          64.4         177.5         120.0            215.0
# 3954726   M  17.0          82.9         212.5         112.5            230.0
# 3954727   M  17.0          91.3         242.5         130.0            257.5
# 3954728   M  18.0         103.6         215.0         120.0            255.0
# 3954729   M  18.0         157.3         240.0         130.0            240.0
#
# ...

# %%
is_natural = (clean_powerlifting['Place'] != 'DD') & (clean_powerlifting['Tested'] == 'Yes')
clean_powerlifting['Group'] = np.where(is_natural, 'Natural', 'Unknown')

clean_powerlifting
# Out:
#         Sex   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  \
# 1         F  43.5          73.2           NaN          90.0              NaN
# 2         F  26.5          60.6           NaN          45.0              NaN
# 3         F  19.5          50.3           NaN          35.0              NaN
# 4         F  19.5          63.7           NaN          42.5              NaN
# 5         M  30.5          82.0           NaN         132.5              NaN
# ...      ..   ...           ...           ...           ...              ...
# 3954725   M  17.0          64.4         177.5         120.0            215.0
# 3954726   M  17.0          82.9         212.5         112.5            230.0
# 3954727   M  17.0          91.3         242.5         130.0            257.5
# 3954728   M  18.0         103.6         215.0         120.0            255.0
# 3954729   M  18.0         157.3         240.0         130.0            240.0
#
# ...

# %%
clean_powerlifting.to_csv('../datasets/cleaned_openpowerlifting.csv', index=False)
