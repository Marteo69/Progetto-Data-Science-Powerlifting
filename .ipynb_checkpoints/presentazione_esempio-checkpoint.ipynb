# %% [markdown]
# Aggiungere questa slide all'inizio per poter personalizzare il progetto
# Renderla di tipo 'skip' per non farla vedere nella presentazione
# |
# |
# V

# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="styles.css">
# Out:
# <link rel="stylesheet" type="text/css" href="styles.css">

# %% [markdown]
# # Scaletta della presentazione
# 1. Introduzione, motivazioni e domande che ci si è posti
# 2. Descrizione del dataset usato
# 3. Desrizione delle analisi effettuate: presentando per ciascuna domanda COME si sono trovate le risposte (calcoli/visualizzazioni)
# 4. Conclusioni (main findings)

# %% [markdown]
# # 1. Introduzione
# 1 o 2 slide con domande come:
# - Perché si è deciso di svolgere questo progetto
# - Perché il dominio è importante
# - Quali sono le conoscenze pregresse
# - Quali sono le domande che ci si è posti e che si cerca di rispondere attraverso lo studio

# %% [markdown]
# # 2. Desrizione dei dati
# 1 o 2 slide per fornire informazioni di contesto riguardanti i dati usati nel progettino
# - Quali dataset sono stati analizzati?
# - Che dati contengono?
# - Che dati interessanti non ci sono?
# - Chi ha creato il dataset?
# - Quando è stato creato il dataset
# - È disponibile online? Aggiungere un riferimento

# %% [markdown]
# # 3. Analisi
# Da 5 a 10 slide per descrivere l'analisi effettuata
# - Presentando come si è risposto a ciascuna domanda
# - Risposte in sequenza come sono state scritte nella prima slide
# - Le risposte devono essere supportare da visualizzazioni o tabelle
# - No codice sorgente nelle slide. Devono contenere solo testo e immagini

# %% [markdown]
# # 4. Conclusioni
# 1 slide con il riassunto della ricerca
# - Presentando una a una le risposte alle domande poste
# - Cosa si è imparato (informazioni nuove)
# - NON scrivere nulla che non sia oggetto delle analisi svolte
# - NO retorica

# %% [markdown]
# # Testo
# Nelle slide mettere poco testo, qualche frase.
